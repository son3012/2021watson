# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# %matplotlib inline

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-3d5af256-8bf4-42ac-94a0-0d6de06a1444',
    'IBM_API_KEY_ID': 'xIKFth5bnHoOe_St_saOqNVyOnPj92xas3jI8FQOl5SE',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'nguyenducbacson-donotdelete-pr-nr8e7yi3ithj9v',
    'FILE': 'titanic.csv'
}
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

if os.environ.get('RUNTIME_ENV_LOCATION_TYPE') == 'external':
    endpoint_898a030403f7485eb967ba42b0aa73e9 = 'https://s3-api.us-geo.objectstorage.softlayer.net'
else:
    endpoint_898a030403f7485eb967ba42b0aa73e9 = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'

client_898a030403f7485eb967ba42b0aa73e9 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='xIKFth5bnHoOe_St_saOqNVyOnPj92xas3jI8FQOl5SE',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url=endpoint_898a030403f7485eb967ba42b0aa73e9)

body = client_898a030403f7485eb967ba42b0aa73e9.get_object(Bucket='nguyenducbacson-donotdelete-pr-nr8e7yi3ithj9v',Key='titanic.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_2 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-3d5af256-8bf4-42ac-94a0-0d6de06a1444',
    'IBM_API_KEY_ID': 'xIKFth5bnHoOe_St_saOqNVyOnPj92xas3jI8FQOl5SE',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'nguyenducbacson-donotdelete-pr-nr8e7yi3ithj9v',
    'FILE': 'titanic.csv'
}

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_855afe22c6b14707b1bf23e1fcd64748 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
streaming_body_1 = client_855afe22c6b14707b1bf23e1fcd64748.get_object(Bucket='datarefineryex1titanic-donotdelete-pr-5bne67qqudo7xb', Key='titanic2.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(streaming_body_1, "__iter__"): streaming_body_1.__iter__ = types.MethodType( __iter__, streaming_body_1 ) 
df_titanic = pd.read_csv(streaming_body_1)
df_titanic.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-65c87a4eefff> in <module>
#      19 # ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
#      20 # pandas documentation: http://pandas.pydata.org/
# ---> 21 streaming_body_1 = client_855afe22c6b14707b1bf23e1fcd64748.get_object(Bucket='datarefineryex1titanic-donotdelete-pr-5bne67qqudo7xb', Key='titanic2.csv')['Body']
#      22 # add missing __iter__ method, so pandas accepts body as file-like object
#      23 if not hasattr(streaming_body_1, "__iter__"): streaming_body_1.__iter__ = types.MethodType( __iter__, streaming_body_1 )
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/client.py in _make_api_call(self, operation_name, api_params)
#     611         else:
#     612             http, parsed_response = self._make_request(
# --> 613                 operation_model, request_dict, request_context)
#     614
#     615         self.meta.events.emit(
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     630     def _make_request(self, operation_model, request_dict, request_context):
#     631         try:
# --> 632             return self._endpoint.make_request(operation_model, request_dict)
#     633         except Exception as e:
#     634             self.meta.events.emit(
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     130     def _send_request(self, request_dict, operation_model):
#     131         attempts = 1
# --> 132         request = self.create_request(request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/endpoint.py in create_request(self, params, operation_model)
#     114                 op_name=operation_model.name)
#     115             self._event_emitter.emit(event_name, request=request,
# --> 116                                      operation_name=operation_model.name)
#     117         prepared_request = self.prepare_request(request)
#     118         return prepared_request
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/hooks.py in emit(self, event_name, **kwargs)
#     354     def emit(self, event_name, **kwargs):
#     355         aliased_event_name = self._alias_event_name(event_name)
# --> 356         return self._emitter.emit(aliased_event_name, **kwargs)
#     357
#     358     def emit_until_response(self, event_name, **kwargs):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/hooks.py in emit(self, event_name, **kwargs)
#     226                  handlers.
#     227         """
# --> 228         return self._emit(event_name, kwargs)
#     229
#     230     def emit_until_response(self, event_name, **kwargs):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     209         for handler in handlers_to_call:
#     210             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 211             response = handler(**kwargs)
#     212             responses.append((handler, response))
#     213             if stop_on_response and response is not None:
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/signers.py in handler(self, operation_name, request, **kwargs)
#      88         # this method is invoked to sign the request.
#      89         # Don't call this method directly.
# ---> 90         return self.sign(operation_name, request)
#      91
#      92     def sign(self, operation_name, request, region_name=None,
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/signers.py in sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     158                     raise e
#     159
# --> 160             auth.add_auth(request)
#     161
#     162     def _choose_signer(self, operation_name, signing_type, context):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/auth.py in add_auth(self, request)
#     851         # from the request body so we can update them with
#     852         # the sigv2 auth params.
# --> 853         self._inject_token_to_request(request)
#     854         return request
#     855
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/auth.py in _inject_token_to_request(self, request)
#     863             # list(headers) will print ['foo', 'foo'].
#     864             del request.headers['Authorization']
# --> 865         request.headers['Authorization'] = ("Bearer %s" % self.credentials.token)
#     866
#     867 # Defined at the bottom instead of the top of the module because the Auth
#
# AttributeError: 'NoneType' object has no attribute 'token'

# %%
df_titanic.info()
df_titanic.describe()

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))

df_titanic['survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.2f%%',ax=ax[0])
ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('survived',data=df_titanic,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
df_titanic['survived'].value_counts()

# %%
df_titanic['age'].hist(bins=20,figsize=(18,8),grid=False);

# %%
df_titanic['age_cat'] = pd.cut(df_titanic['age'], bins=[0, 10, 20, 50, 100], 
                             include_lowest=True, labels=['baby', 'teenage', 'adult', 'old'])
plt.figure(figsize=[12,4])
plt.subplot(131)
sns.barplot('pclass', 'survived', data=df_titanic)
plt.subplot(132)
sns.barplot('age_cat', 'survived', data=df_titanic)
plt.subplot(133)
sns.barplot('sex', 'survived', data=df_titanic)
plt.subplots_adjust(top=1, bottom=0.1, left=0.10, right=1, hspace=0.5, wspace=0.5)
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))
sns.countplot('sex',data=df_titanic, ax=ax[0])
ax[0].set_title('Count of Passengers by Sex')

sns.countplot('sex',hue='survived',data=df_titanic, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
df_titanic.isnull().sum()

# %%
# null이 실제로 몇 번 row에 있는지 확인한다
print("Rows where fare value is missing:")
df_titanic[df_titanic['fare'].isnull()]

# %%
print("Rows where age value is missing:")
df_titanic[df_titanic['age'].isnull()]

# %%
# 중요! - 데이터 정제2 - 컬럼값이 NULL이 아닌 것만 필터링
df_titanic = df_titanic[df_titanic['age'].notna()]
df_titanic = df_titanic[df_titanic['fare'].notna()]
df_titanic.isnull().sum()

# %%
print("Rows where fare value is missing:")
df_titanic[df_titanic['fare'].isnull()]

# %%
print("Rows where age value is missing:")
df_titanic[df_titanic['age'].isnull()]

# %%
df_titanic.sex.dtype

# %%
# sex를 문자열에서 정수로 변경하는 함수를 정의. LabelEncoder.fit()은 알파벳의 순서로 sort해서 encoding한다
from sklearn.preprocessing import LabelEncoder
def sex_to_int(data):
    le = LabelEncoder()
    le.fit(["male","female"])
    data["sex"]=le.transform(data["sex"]) 
    return data

# %%
# sex를 문자열에서 정수로 변경하는 함수를 정의
df_titanic = sex_to_int(df_titanic)
df_titanic.sex.dtype

# %%
x_data = df_titanic.values[:, [0,3,4,5,6,8]]
y_data = df_titanic.values[:, [1]]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.1, random_state=7)

# %%
x_data

# %%
y_data

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers.core import Dense
np.random.seed(7)

print('tensorflow version : ', tf.__version__)
print('keras version : ', keras.__version__)

# %%
model = Sequential()
model.add(Dense(255, input_shape=(6,), activation='relu'))
model.add(Dense((1), activation='sigmoid'))
model.compile(loss='mse', optimizer='Adam', metrics=['accuracy'])
model.summary()

# %%
hist = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)

plt.figure(figsize=(12,8))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.legend(['loss','val_loss', 'acc','val_acc'])
plt.show()

# %%
dicaprio = np.array([3., 1., 19., 0., 0., 5.]).reshape(1,6)
winslet = np.array([1., 0., 17., 1., 2., 100.]).reshape(1,6)

# %%
model.predict(dicaprio)

# %%
model.predict(winslet)
